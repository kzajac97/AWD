# %%
from google.colab import drive

drive.mount('/content/gdrive')
root_path = "gdrive/My Drive/Python/AWD"
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import sys

sys.path.append(root_path)

# %%
import os
import time

import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt
from skimage import io

from src.models.transfer import style_transfer

# %%
tf.compat.v1.disable_eager_execution()

# %%
generated_image = style_transfer(
    content_image_path=os.path.join(root_path, r"data/content/german-town.jpg"),
    style_image_path=os.path.join(root_path, r"data/style/Starry-Night-Van-Gogh.jpg"),
    outputs_dir=os.path.join(root_path, r"data/generated"),
    n_epochs=5,
    save_frequency=None,
)
# Out:
# 100%|██████████| 5/5 [01:54<00:00, 22.89s/it]

# %%
figure = plt.figure(figsize=[16, 9])
_ = plt.imshow(generated_image)
